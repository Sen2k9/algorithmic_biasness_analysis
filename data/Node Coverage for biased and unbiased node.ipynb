# %% [markdown]
# # Importing data for unbiased algorithm

# %%
import pandas as pd
import seaborn as sns
tips2 = pd.read_csv("algo-bias.csv")
s = []
for each in tips2["Average node coverage(%)"]:
    a = str(each).split("%")
    s.append(int(a[0]))
tips2["Average node coverage(%)"]= s
op = []
for each in tips2["Optimal node coverage(%)"]:
    a = str(each).split("%")
    op.append(int(a[0]))
tips2["Optimal node coverage(%)"] = op
print(tips2.head())
# Out:
#                        Techniques  # of nodes  #iteration  \
# 0               Genetic Algorithm          10         200
# 1  Hill Climbing with random walk          10         200
# 2             Simulated Annealing          10         200
# 3                     Tabu Search          10         200
# 4               Genetic Algorithm          20         200
#
#    Average node coverage(%)  Optimal node coverage(%)  Optimal value
# 0                        59                        60            174
# 1                        47                        60            200
# 2                        58                        60            200
# 3                        40                        60            200
# 4                        45                        45            601

# %% [markdown]
# # Ploting for Average node coverage for four metaheuristic algorithms (genetic algorithm, hill climbing with random walk, simulated annealing and tabu search)
#
# # each having 200 iteration. The average node coverage = sum(optimal coverage for each generation)/200
#
# # The figure shows that the average node coverage increases with the increase of node numbers

# %%
#Average node
import matplotlib.pyplot as plt
plt.figure(figsize=(15,8))
#sns.set_style("whitegrid")
plt.title('# of nodes vs Average node Coverage')
sns.scatterplot(x="# of nodes", y="Average node coverage(%)", data=tips2, marker='D',hue="Techniques",palette="deep")
plt.savefig('avg_coverage.jpg')

# %% [markdown]
# # The figure below is the boxplot representation of how four different algorithm varies for same node numbers and generation.
#
# # For example, when number of nodes is 10 for 200 generation, the boxplot has lower bound at 40% and upper bound at 58% with 53% mean approximately.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,5))
#sns.set_style("whitegrid")
plt.title('# of nodes vs Average node Coverage')
sns.boxplot(
    data=tips2,
x="# of nodes", 
    y="Average node coverage(%)",
    color='red'
)
plt.savefig('avg_coverage_boxplot.jpg')

# %% [markdown]
# # The five figures below is the regression plot for average node coverage against number of nodes.
#
# # The plot shows that when number of nodes get increased all the metaheuristic algorithms ( in our case four) tends to have positive linear relationship.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
plt.title('# of nodes vs Optimal node Coverage')
sns.regplot(x="# of nodes", y="Average node coverage(%)", data=tips2)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
plt.title('# of nodes vs Average node Coverage')
sns.regplot(x="# of nodes", y="Average node coverage(%)", data=tips2, ci=90)
plt.savefig('avg_coverage_regplot.jpg')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
plt.title('# of nodes vs Average node Coverage')
sns.regplot(x="# of nodes", y="Average node coverage(%)", data=tips2, x_bins=11)
plt.savefig('avg_coverage_regplot_x_bin.jpg')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
import numpy as np
sns.regplot(x="# of nodes", y="Average node coverage(%)", data=tips2, x_estimator=np.mean)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(25,5))
import numpy as np
sns.lmplot(x="# of nodes", y="Average node coverage(%)", data=tips2, x_bins=11)

# %% [markdown]
# # The figure below is the ploting for Optimal node coverage for four metaheuristic algorithms (genetic algorithm, hill climbing with random walk, simulated annealing and tabu search) each having 200 iteration.
#
# # The optimal node coverage here means that we were interested to choose only the optimal result (maximizing function) throughout the 200 generations.
#
# # The figure shows that the optimal node coverage also increases, like as average node coverage case, with the increase of node numbers

# %%
#Optimal node
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))

plt.title('Number of nodes vs Optimal node Coverage (Unbiased)')
#sns.set_style("whitegrid")
sns.scatterplot(x="# of nodes", y="Optimal node coverage(%)", data=tips2, hue="Techniques",palette="deep")
plt.savefig('optimal_coverage_unbiased.jpg')

# %% [markdown]
# # The figure below is the boxplot representation of how four different algorithm varies for same node numbers and generation in respect of optimal node coverage.
#
# # For example, when number of nodes is 50 for 200 generation, the boxplot has lower bound at 50% and upper bound at 56% with 53% as mean approximately.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,5))
#sns.set_style("whitegrid")
plt.title('# of nodes vs Optimal node Coverage')
sns.boxplot(
    data=tips2,
x="# of nodes", 
    y="Optimal node coverage(%)",
    color='red'
)
plt.savefig('optimal_coverage_boxplot.jpg')

# %% [markdown]
# # The five figures below is the regression plot for optimal node coverage against number of nodes.
#
# # The plot shows that when number of nodes get increased all the metaheuristic algorithms ( in our case four) tends to have positive linear relationship same as average node coverage case.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
plt.title('Number of nodes vs Optimal node Coverage (unbiased)')
sns.regplot(x="# of nodes", y="Optimal node coverage(%)", data=tips2, ci=90)
plt.savefig('optimal_coverage_regplot_unbiased.jpg')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
plt.title('# of nodes vs Optimal node Coverage')
sns.regplot(x="# of nodes", y="Optimal node coverage(%)", data=tips2, x_bins=11)
plt.savefig('optimal_coverage_regplot_x_bin.jpg')

# %% [markdown]
# # The same results have been shown for four biased algorithms with same dataset. In our case metaheuristic algorithms (genetic algorithm, hill climbing with random walk, simulated annealing, tabu search)

# %%
import pandas as pd

tips2 = pd.read_csv("algo-bias1.csv")
s = []
#print(tips2["Averag "])
for each in tips2["Average node coverage(%)"]:
    a = str(each).split("%")
    s.append(int(a[0]))
tips2["Average node coverage(%)"]= s
op = []
for each in tips2["Optimal node coverage(%)"]:
    a = str(each).split("%")
    op.append(int(a[0]))
tips2["Optimal node coverage(%)"] = op
print(tips2.head())
# Out:
#                        Techniques  # of nodes  # iteration  \
# 0               Genetic Algorithm          10        200.0
# 1  Hill Climbing with random walk          10          NaN
# 2             Simulated Annealing          10          NaN
# 3                     Tabu Search          10          NaN
# 4               Genetic Algorithm          20        200.0
#
#    Average node coverage(%)  Optimal node coverage(%)  Optimal Value
# 0                        59                        60            188
# 1                        42                        60            188
# 2                        58                        60            188
# 3                        42                        60            188
# 4                        49                        50            499

# %%
#Average node
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,8))
#sns.set_style("whitegrid")
plt.title('# of nodes vs Average node Coverage')
sns.scatterplot(x="# of nodes", y="Average node coverage(%)", data=tips2, marker='D',hue="Techniques",palette="deep")
plt.savefig('avg_coverage.jpg')

import matplotlib.pyplot as plt
plt.figure(figsize=(20,5))
#sns.set_style("whitegrid")
plt.title('# of nodes vs Average node Coverage')
sns.boxplot(
    data=tips2,
x="# of nodes", 
    y="Average node coverage(%)",
    color='red'
)
plt.savefig('avg_coverage_boxplot.jpg')

import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
plt.title('# of nodes vs Optimal node Coverage')
sns.regplot(x="# of nodes", y="Average node coverage(%)", data=tips2)

import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
plt.title('# of nodes vs Average node Coverage')
sns.regplot(x="# of nodes", y="Average node coverage(%)", data=tips2, ci=90)
plt.savefig('avg_coverage_regplot.jpg')

import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
plt.title('# of nodes vs Average node Coverage')
sns.regplot(x="# of nodes", y="Average node coverage(%)", data=tips2, x_bins=11)
plt.savefig('avg_coverage_regplot_x_bin.jpg')

import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
import numpy as np
sns.regplot(x="# of nodes", y="Average node coverage(%)", data=tips2, x_estimator=np.mean)

import matplotlib.pyplot as plt
plt.figure(figsize=(25,5))
import numpy as np
sns.lmplot(x="# of nodes", y="Average node coverage(%)", data=tips2, x_bins=11)

#Optimal node
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))

plt.title('# of nodes vs Optimal node Coverage')
#sns.set_style("whitegrid")
sns.scatterplot(x="# of nodes", y="Optimal node coverage(%)", data=tips2, hue="Techniques",palette="deep")
plt.savefig('optimal_coverage.jpg')

import matplotlib.pyplot as plt
plt.figure(figsize=(20,5))
#sns.set_style("whitegrid")
plt.title('# of nodes vs Optimal node Coverage')
sns.boxplot(
    data=tips2,
x="# of nodes", 
    y="Optimal node coverage(%)",
    color='red'
)
plt.savefig('optimal_coverage_boxplot.jpg')

import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
plt.title('Number of nodes vs Optimal node Coverage (biased)')
sns.regplot(x="# of nodes", y="Optimal node coverage(%)", data=tips2, ci=90)
plt.savefig('optimal_coverage_regplot_biased.jpg')

import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
plt.title('# of nodes vs Optimal node Coverage')
sns.regplot(x="# of nodes", y="Optimal node coverage(%)", data=tips2, x_bins=11)
plt.savefig('optimal_coverage_regplot_x_bin.jpg')

# %% [markdown]
# # The figures below shows the absolute difference between the node coverage for biased and unbiased metaheuristic algorithms in case of optimal node coverage.
#
# # From the ploting we can see that, there is a significant linear relationship of absolute difference for node coverage.

# %%
import pandas as pd

tips2 = pd.read_csv("Absolute_difference.csv")
# s = []
# #print(tips2["Averag "])
# for each in tips2["Average node coverage(%)"]:
#     a = str(each).split("%")
#     s.append(int(a[0]))
# tips2["Average node coverage(%)"]= s
# op = []
# for each in tips2["Optimal node coverage(%)"]:
#     a = str(each).split("%")
#     op.append(int(a[0]))
# tips2["Optimal node coverage(%)"] = op
print(tips2.head())

#Average node
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,8))
#sns.set_style("whitegrid")
plt.title('# of nodes vs difference between unbiased and biased algorithm')
sns.scatterplot(x="# of nodes", y="Absolute difference", data=tips2, marker='D',hue="Techniques",palette="deep")
#plt.savefig('avg_coverage.jpg')

import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
plt.title('Number of nodes vs difference between unbiased and biased algorithm')
sns.regplot(x="# of nodes", y="Absolute difference", data=tips2)
plt.savefig('optimal_coverage_regplot_biased_unbiased.jpg')

import matplotlib.pyplot as plt
plt.figure(figsize=(25,5))
import numpy as np
sns.lmplot(x="# of nodes", y="Absolute difference", data=tips2, x_bins=11)
# Out:
#                        Techniques  # of nodes  \
# 0               Genetic Algorithm          10
# 1  Hill Climbing with random walk          10
# 2             Simulated Annealing          10
# 3                     Tabu Search          10
# 4               Genetic Algorithm          20
#
#    Optimal node coverage unbiased(%)  Optimal node coverage biased(%)  \
# 0                                 60                               60
# 1                                 60                               60
# 2                                 60                               60
# 3                                 60                               60
# 4                                 45                               50
#
#    Unnamed: 4  Absolute difference
# 0         NaN                    0
# 1         NaN                    0
# 2         NaN                    0
# 3         NaN                    0
# 4         NaN                    5

# %% [markdown]
# # So we can conclude that, biased and unbiased algorithm behaves differently.
#
# # We can test the biasness of an algorithm by testing its coverage pattern.
